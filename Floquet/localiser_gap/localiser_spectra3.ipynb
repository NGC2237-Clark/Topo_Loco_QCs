# %%
# %load_ext autoreload

# %%
import numpy as np
import matplotlib.pyplot as plt
import AFAI_parallelGPU as afai_parallel
import torch

# %%
# %autoreload 2

# %%
period = 2
hopping1 = - np.pi/(2)
hopping2 = - 3 * np.pi/(2)
hopping3 = - 5 * np.pi/(2)

# %%
model20 = afai_parallel.tb_floquet_tbc_cuda(period, 1, hopping3, ny=20, nx=20, device='cuda:0')
model30 = afai_parallel.tb_floquet_tbc_cuda(period, 1, hopping3, ny=30, nx=30, device='cuda:0')
model40 = afai_parallel.tb_floquet_tbc_cuda(period, 1, hopping3, ny=40, nx=40, device='cuda:0')
model50 = afai_parallel.tb_floquet_tbc_cuda(period, 1, hopping3, ny=50, nx=50, device='cuda:0')

# %%
model30_1 = afai_parallel.tb_floquet_tbc_cuda(period, 1, hopping1, ny=30, nx=30, device='cuda:0')

# %%
model30_2 = afai_parallel.tb_floquet_tbc_cuda(period, 1, hopping2, ny=30, nx=30, device='cuda:0')

# %%
normalised1 = model30_1.normalised_localiser_gap(epsilonT = 0, kappa =0.1, steps_per_segment=100, vdT=0, plot=True)
# Out:
# Computing localizer gap for x = -3
# Computing localizer gap for y = -3
# Computing localizer gap for y = -2
# Computing localizer gap for y = -1
# Computing localizer gap for y = 0
# Computing localizer gap for y = 1
# Computing localizer gap for y = 2
# Computing localizer gap for y = 3
# Computing localizer gap for y = 4
# Computing localizer gap for y = 5
# Computing localizer gap for y = 6
# Computing localizer gap for y = 7
# Computing localizer gap for y = 8
# Computing localizer gap for y = 9
# Computing localizer gap for y = 10
# Computing localizer gap for y = 11
# Computing localizer gap for y = 12
# Computing localizer gap for y = 13
# Computing localizer gap for y = 14
# Computing localizer gap for y = 15
# Computing localizer gap for y = 16
# Computing localizer gap for y = 17
# Computing localizer gap for y = 18
# Computing localizer gap for y = 19
# Computing localizer gap for y = 20
# Computing localizer gap for y = 21
# Computing localizer gap for y = 22
# ...

# %% [markdown]
# change the log

# %%
chern_marker0_0 = model30_1.compute_chern_marker(epsilonT = 0, kappa =0.01, steps_per_segment=100, vdT=0, plot=True)
# Out:
# Computing Chern marker for x = 0
# Computing Chern marker for y = 0
# Computing Chern marker for y = 1
# Computing Chern marker for y = 2
# Computing Chern marker for y = 3
# Computing Chern marker for y = 4
# Computing Chern marker for y = 5
# Computing Chern marker for y = 6
# Computing Chern marker for y = 7
# Computing Chern marker for y = 8
# Computing Chern marker for y = 9
# Computing Chern marker for y = 10
# Computing Chern marker for y = 11
# Computing Chern marker for y = 12
# Computing Chern marker for y = 13
# Computing Chern marker for y = 14
# Computing Chern marker for y = 15
# Computing Chern marker for y = 16
# Computing Chern marker for y = 17
# Computing Chern marker for y = 18
# Computing Chern marker for y = 19
# Computing Chern marker for y = 20
# Computing Chern marker for y = 21
# Computing Chern marker for y = 22
# Computing Chern marker for y = 23
# Computing Chern marker for y = 24
# Computing Chern marker for y = 25
# Computing Chern marker for y = 26
# ...

# %%
chern_marker0_pi = model30_1.compute_chern_marker(epsilonT = torch.pi, kappa =0.01, steps_per_segment=100, vdT=0, plot=True)
# Out:
# Computing Chern marker for x = 0
# Computing Chern marker for y = 0
# Computing Chern marker for y = 1
# Computing Chern marker for y = 2
# Computing Chern marker for y = 3
# Computing Chern marker for y = 4
# Computing Chern marker for y = 5
# Computing Chern marker for y = 6
# Computing Chern marker for y = 7
# Computing Chern marker for y = 8
# Computing Chern marker for y = 9
# Computing Chern marker for y = 10
# Computing Chern marker for y = 11
# Computing Chern marker for y = 12
# Computing Chern marker for y = 13
# Computing Chern marker for y = 14
# Computing Chern marker for y = 15
# Computing Chern marker for y = 16
# Computing Chern marker for y = 17
# Computing Chern marker for y = 18
# Computing Chern marker for y = 19
# Computing Chern marker for y = 20
# Computing Chern marker for y = 21
# Computing Chern marker for y = 22
# Computing Chern marker for y = 23
# Computing Chern marker for y = 24
# Computing Chern marker for y = 25
# Computing Chern marker for y = 26
# ...

# %%
normalised_0 = model30.normalised_localiser_gap(epsilonT = 0, kappa =0.01, steps_per_segment=100, vdT=0, plot=True)
# Out:
# Computing localizer gap for x = -3
# Computing localizer gap for y = -3
# Computing localizer gap for y = -2
# Computing localizer gap for y = -1
# Computing localizer gap for y = 0
# Computing localizer gap for y = 1
# Computing localizer gap for y = 2
# Computing localizer gap for y = 3
# Computing localizer gap for y = 4
# Computing localizer gap for y = 5
# Computing localizer gap for y = 6
# Computing localizer gap for y = 7
# Computing localizer gap for y = 8
# Computing localizer gap for y = 9
# Computing localizer gap for y = 10
# Computing localizer gap for y = 11
# Computing localizer gap for y = 12
# Computing localizer gap for y = 13
# Computing localizer gap for y = 14
# Computing localizer gap for y = 15
# Computing localizer gap for y = 16
# Computing localizer gap for y = 17
# Computing localizer gap for y = 18
# Computing localizer gap for y = 19
# Computing localizer gap for y = 20
# Computing localizer gap for y = 21
# Computing localizer gap for y = 22
# ...

# %%
normalised = model30.normalised_localiser_gap(epsilonT = 0, kappa =0.1, steps_per_segment=100, vdT=0, plot=True)
# Out:
# Computing localizer gap for x = -3
# Computing localizer gap for y = -3
# Computing localizer gap for y = -2
# Computing localizer gap for y = -1
# Computing localizer gap for y = 0
# Computing localizer gap for y = 1
# Computing localizer gap for y = 2
# Computing localizer gap for y = 3
# Computing localizer gap for y = 4
# Computing localizer gap for y = 5
# Computing localizer gap for y = 6
# Computing localizer gap for y = 7
# Computing localizer gap for y = 8
# Computing localizer gap for y = 9
# Computing localizer gap for y = 10
# Computing localizer gap for y = 11
# Computing localizer gap for y = 12
# Computing localizer gap for y = 13
# Computing localizer gap for y = 14
# Computing localizer gap for y = 15
# Computing localizer gap for y = 16
# Computing localizer gap for y = 17
# Computing localizer gap for y = 18
# Computing localizer gap for y = 19
# Computing localizer gap for y = 20
# Computing localizer gap for y = 21
# Computing localizer gap for y = 22
# ...

# %%
chern_marker1_0 = model30.compute_chern_marker(epsilonT = 0, kappa =0.01, steps_per_segment=100, vdT=0, plot=True)
# Out:
# Computing Chern marker for x = 0
# Computing Chern marker for y = 0
# Computing Chern marker for y = 1
# Computing Chern marker for y = 2
# Computing Chern marker for y = 3
# Computing Chern marker for y = 4
# Computing Chern marker for y = 5
# Computing Chern marker for y = 6
# Computing Chern marker for y = 7
# Computing Chern marker for y = 8
# Computing Chern marker for y = 9
# Computing Chern marker for y = 10
# Computing Chern marker for y = 11
# Computing Chern marker for y = 12
# Computing Chern marker for y = 13
# Computing Chern marker for y = 14
# Computing Chern marker for y = 15
# Computing Chern marker for y = 16
# Computing Chern marker for y = 17
# Computing Chern marker for y = 18
# Computing Chern marker for y = 19
# Computing Chern marker for y = 20
# Computing Chern marker for y = 21
# Computing Chern marker for y = 22
# Computing Chern marker for y = 23
# Computing Chern marker for y = 24
# Computing Chern marker for y = 25
# Computing Chern marker for y = 26
# ...

# %%
normalised_pi = model30.normalised_localiser_gap(epsilonT = torch.pi, kappa =0.01, steps_per_segment=100, vdT=0, plot=True)
# Out:
# Computing localizer gap for x = -3
# Computing localizer gap for y = -3
# Computing localizer gap for y = -2
# Computing localizer gap for y = -1
# Computing localizer gap for y = 0
# Computing localizer gap for y = 1
# Computing localizer gap for y = 2
# Computing localizer gap for y = 3
# Computing localizer gap for y = 4
# Computing localizer gap for y = 5
# Computing localizer gap for y = 6
# Computing localizer gap for y = 7
# Computing localizer gap for y = 8
# Computing localizer gap for y = 9
# Computing localizer gap for y = 10
# Computing localizer gap for y = 11
# Computing localizer gap for y = 12
# Computing localizer gap for y = 13
# Computing localizer gap for y = 14
# Computing localizer gap for y = 15
# Computing localizer gap for y = 16
# Computing localizer gap for y = 17
# Computing localizer gap for y = 18
# Computing localizer gap for y = 19
# Computing localizer gap for y = 20
# Computing localizer gap for y = 21
# Computing localizer gap for y = 22
# ...

# %%
chern_marker1_pi = model30.compute_chern_marker(epsilonT = torch.pi, kappa =0.01, steps_per_segment=100, vdT=0, plot=True)
# Out:
# Computing Chern marker for x = 0
# Computing Chern marker for y = 0
# Computing Chern marker for y = 1
# Computing Chern marker for y = 2
# Computing Chern marker for y = 3
# Computing Chern marker for y = 4
# Computing Chern marker for y = 5
# Computing Chern marker for y = 6
# Computing Chern marker for y = 7
# Computing Chern marker for y = 8
# Computing Chern marker for y = 9
# Computing Chern marker for y = 10
# Computing Chern marker for y = 11
# Computing Chern marker for y = 12
# Computing Chern marker for y = 13
# Computing Chern marker for y = 14
# Computing Chern marker for y = 15
# Computing Chern marker for y = 16
# Computing Chern marker for y = 17
# Computing Chern marker for y = 18
# Computing Chern marker for y = 19
# Computing Chern marker for y = 20
# Computing Chern marker for y = 21
# Computing Chern marker for y = 22
# Computing Chern marker for y = 23
# Computing Chern marker for y = 24
# Computing Chern marker for y = 25
# Computing Chern marker for y = 26
# ...

# %%
normalised_2 = model30_2.normalised_localiser_gap(epsilonT = 0, kappa =0.01, steps_per_segment=100, vdT=0, plot=True)
# Out:
# Computing localizer gap for x = -3
# Computing localizer gap for y = -3
# Computing localizer gap for y = -2
# Computing localizer gap for y = -1
# Computing localizer gap for y = 0
# Computing localizer gap for y = 1
# Computing localizer gap for y = 2
# Computing localizer gap for y = 3
# Computing localizer gap for y = 4
# Computing localizer gap for y = 5
# Computing localizer gap for y = 6
# Computing localizer gap for y = 7
# Computing localizer gap for y = 8
# Computing localizer gap for y = 9
# Computing localizer gap for y = 10
# Computing localizer gap for y = 11
# Computing localizer gap for y = 12
# Computing localizer gap for y = 13
# Computing localizer gap for y = 14
# Computing localizer gap for y = 15
# Computing localizer gap for y = 16
# Computing localizer gap for y = 17
# Computing localizer gap for y = 18
# Computing localizer gap for y = 19
# Computing localizer gap for y = 20
# Computing localizer gap for y = 21
# Computing localizer gap for y = 22
# ...

# %%
chern_marker2_0 = model30_2.compute_chern_marker(epsilonT = 0, kappa =0.01, steps_per_segment=100, vdT=0, plot=True)
# Out:
# Computing Chern marker for x = 0
# Computing Chern marker for y = 0
# Computing Chern marker for y = 1
# Computing Chern marker for y = 2
# Computing Chern marker for y = 3
# Computing Chern marker for y = 4
# Computing Chern marker for y = 5
# Computing Chern marker for y = 6
# Computing Chern marker for y = 7
# Computing Chern marker for y = 8
# Computing Chern marker for y = 9
# Computing Chern marker for y = 10
# Computing Chern marker for y = 11
# Computing Chern marker for y = 12
# Computing Chern marker for y = 13
# Computing Chern marker for y = 14
# Computing Chern marker for y = 15
# Computing Chern marker for y = 16
# Computing Chern marker for y = 17
# Computing Chern marker for y = 18
# Computing Chern marker for y = 19
# Computing Chern marker for y = 20
# Computing Chern marker for y = 21
# Computing Chern marker for y = 22
# Computing Chern marker for y = 23
# Computing Chern marker for y = 24
# Computing Chern marker for y = 25
# Computing Chern marker for y = 26
# ...

# %%
normalised_pi_2 = model30_2.normalised_localiser_gap(epsilonT = torch.pi, kappa =0.01, steps_per_segment=100, vdT=0, plot=True)
# Out:
# Computing localizer gap for x = -3
# Computing localizer gap for y = -3
# Computing localizer gap for y = -2
# Computing localizer gap for y = -1
# Computing localizer gap for y = 0
# Computing localizer gap for y = 1
# Computing localizer gap for y = 2
# Computing localizer gap for y = 3
# Computing localizer gap for y = 4
# Computing localizer gap for y = 5
# Computing localizer gap for y = 6
# Computing localizer gap for y = 7
# Computing localizer gap for y = 8
# Computing localizer gap for y = 9
# Computing localizer gap for y = 10
# Computing localizer gap for y = 11
# Computing localizer gap for y = 12
# Computing localizer gap for y = 13
# Computing localizer gap for y = 14
# Computing localizer gap for y = 15
# Computing localizer gap for y = 16
# Computing localizer gap for y = 17
# Computing localizer gap for y = 18
# Computing localizer gap for y = 19
# Computing localizer gap for y = 20
# Computing localizer gap for y = 21
# Computing localizer gap for y = 22
# ...

# %%
chern_marker2 = model30_2.compute_chern_marker(epsilonT = torch.pi, kappa =0.01, steps_per_segment=100, vdT=0, plot=True)
# Out:
# Computing Chern marker for x = 0
# Computing Chern marker for y = 0
# Computing Chern marker for y = 1
# Computing Chern marker for y = 2
# Computing Chern marker for y = 3
# Computing Chern marker for y = 4
# Computing Chern marker for y = 5
# Computing Chern marker for y = 6
# Computing Chern marker for y = 7
# Computing Chern marker for y = 8
# Computing Chern marker for y = 9
# Computing Chern marker for y = 10
# Computing Chern marker for y = 11
# Computing Chern marker for y = 12
# Computing Chern marker for y = 13
# Computing Chern marker for y = 14
# Computing Chern marker for y = 15
# Computing Chern marker for y = 16
# Computing Chern marker for y = 17
# Computing Chern marker for y = 18
# Computing Chern marker for y = 19
# Computing Chern marker for y = 20
# Computing Chern marker for y = 21
# Computing Chern marker for y = 22
# Computing Chern marker for y = 23
# Computing Chern marker for y = 24
# Computing Chern marker for y = 25
# Computing Chern marker for y = 26
# ...

# %%
chern_marker2_pi = model30_2.compute_chern_marker(epsilonT = torch.pi, kappa =0.1, steps_per_segment=100, vdT=0, plot=True)
# Out:
# Computing Chern marker for x = 0
# Computing Chern marker for y = 0
# Computing Chern marker for y = 1
# Computing Chern marker for y = 2
# Computing Chern marker for y = 3
# Computing Chern marker for y = 4
# Computing Chern marker for y = 5
# Computing Chern marker for y = 6
# Computing Chern marker for y = 7
# Computing Chern marker for y = 8
# Computing Chern marker for y = 9
# Computing Chern marker for y = 10
# Computing Chern marker for y = 11
# Computing Chern marker for y = 12
# Computing Chern marker for y = 13
# Computing Chern marker for y = 14
# Computing Chern marker for y = 15
# Computing Chern marker for y = 16
# Computing Chern marker for y = 17
# Computing Chern marker for y = 18
# Computing Chern marker for y = 19
# Computing Chern marker for y = 20
# Computing Chern marker for y = 21
# Computing Chern marker for y = 22
# Computing Chern marker for y = 23
# Computing Chern marker for y = 24
# Computing Chern marker for y = 25
# Computing Chern marker for y = 26
# ...

# %% [markdown]
# Add disorder

# %%
chern_marker_pi_dis = model30.compute_chern_marker(epsilonT = torch.pi, kappa =0.01, steps_per_segment=100, vdT=13, plot=True)
# Out:
# Computing Chern marker for x = 0
# Computing Chern marker for y = 0
# Computing Chern marker for y = 1
# Computing Chern marker for y = 2
# Computing Chern marker for y = 3
# Computing Chern marker for y = 4
# Computing Chern marker for y = 5
# Computing Chern marker for y = 6
# Computing Chern marker for y = 7
# Computing Chern marker for y = 8
# Computing Chern marker for y = 9
# Computing Chern marker for y = 10
# Computing Chern marker for y = 11
# Computing Chern marker for y = 12
# Computing Chern marker for y = 13
# Computing Chern marker for y = 14
# Computing Chern marker for y = 15
# Computing Chern marker for y = 16
# Computing Chern marker for y = 17
# Computing Chern marker for y = 18
# Computing Chern marker for y = 19
# Computing Chern marker for y = 20
# Computing Chern marker for y = 21
# Computing Chern marker for y = 22
# Computing Chern marker for y = 23
# Computing Chern marker for y = 24
# Computing Chern marker for y = 25
# Computing Chern marker for y = 26
# ...

# %%
chern_marker_0_dis = model30.compute_chern_marker(epsilonT = 0, kappa =0.01, steps_per_segment=100, vdT=13, plot=True)
# Out:
# Computing Chern marker for x = 0
# Computing Chern marker for y = 0
# Computing Chern marker for y = 1
# Computing Chern marker for y = 2
# Computing Chern marker for y = 3
# Computing Chern marker for y = 4
# Computing Chern marker for y = 5
# Computing Chern marker for y = 6
# Computing Chern marker for y = 7
# Computing Chern marker for y = 8
# Computing Chern marker for y = 9
# Computing Chern marker for y = 10
# Computing Chern marker for y = 11
# Computing Chern marker for y = 12
# Computing Chern marker for y = 13
# Computing Chern marker for y = 14
# Computing Chern marker for y = 15
# Computing Chern marker for y = 16
# Computing Chern marker for y = 17
# Computing Chern marker for y = 18
# Computing Chern marker for y = 19
# Computing Chern marker for y = 20
# Computing Chern marker for y = 21
# Computing Chern marker for y = 22
# Computing Chern marker for y = 23
# Computing Chern marker for y = 24
# Computing Chern marker for y = 25
# Computing Chern marker for y = 26
# ...
